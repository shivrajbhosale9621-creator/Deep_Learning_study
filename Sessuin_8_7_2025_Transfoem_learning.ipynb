# %% [markdown]
# Google has taken 1.3m images which consist 1000 classes
# our MNIST daa set 60k 10 classes
# Every image they draw the bounding box it will 4 coordinated
# top left corner(x,y)
# Bottom right corner(x+w,y+h)
# They created a dataset
# 1.Image
# 2.Cordinated
# 3.Class
# This data pass ro CNN Then they train the model once they got the good accuracy the save the model
# 1.Model configutatin

# %% [markdown]
# ## mobile net
#
# - object detication based on CNN architects
#
# - Deveoped by google
#
# - it has taken 1.3 millions images which consists of 1000 of characters
#
# - our MNIST data ser has 60K images with 10 classes
#
# - every image they will draw the bounding box it will be having 4 coordinates
#
# - to left corner(x,y)
#
# - botton right (x+w,y+h)
#
# This data is processed to CNN then train the model once thery got good accuracy then save the model
#
# ## import mobilenet using keras model

# %% [markdown]
# # Transfer learning
# - It is pre trined model
# -already trained we using for our use cases
# -this type of learninh is called transfer learning
#
# ## 1.model configuration
#
#  - How many layers
#  - what are the parameters

# %% [markdown]
# ## Using Keras

# %%
import keras
dir(keras.applications)
# Out:
# ['ConvNeXtBase',
#  'ConvNeXtLarge',
#  'ConvNeXtSmall',
#  'ConvNeXtTiny',
#  'ConvNeXtXLarge',
#  'DenseNet121',
#  'DenseNet169',
#  'DenseNet201',
#  'EfficientNetB0',
#  'EfficientNetB1',
#  'EfficientNetB2',
#  'EfficientNetB3',
#  'EfficientNetB4',
#  'EfficientNetB5',
#  'EfficientNetB6',
#  'EfficientNetB7',
#  'EfficientNetV2B0',
#  'EfficientNetV2B1',
#  'EfficientNetV2B2',
#  'EfficientNetV2B3',
#  'EfficientNetV2L',
#  'EfficientNetV2M',
#  'EfficientNetV2S',
#  'InceptionResNetV2',
#  'InceptionV3',
#  'MobileNet',
#  'MobileNetV2',
#  'MobileNetV3Large',
#  'MobileNetV3Small',
#  'NASNetLarge',
#  'NASNetMobile',
#  'ResNet101',
#  'ResNet101V2',
#  'ResNet152',
#  'ResNet152V2',
#  'ResNet50',
#  'ResNet50V2',
#  'VGG16',
#  'VGG19',
#  'Xception',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'convnext',
#  'densenet',
#  'efficientnet',
#  'efficientnet_v2',
# ...

# %%
mobile=keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
dir(mobile)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_adjust_input_rank',
#  '_aggregate_additional_loss',
#  '_allow_non_tensor_positional_args',
#  '_api_export_path',
#  '_api_export_symbol_id',
#  '_assert_compile_called',
#  '_assert_input_compatibility',
#  '_assign_variable_values',
#  '_auto_config',
#  '_build_by_run_for_kwargs',
#  '_build_by_run_for_single_pos_arg',
#  '_build_shapes_dict',
#  '_call_has_mask_arg',
#  '_call_has_training_arg',
#  '_call_signature',
#  '_called',
#  '_check_quantize_args',
# ...

# %%
mobile.name
# Out:
# 'mobilenet_1.00_224'

# %%
mobile.input
# Out:
# <KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>

# %%
mobile.input_dtype
# Out:
# 'float32'

# %%
mobile.input_shape
# Out:
# (None, 224, 224, 3)

# %%
mobile.input_spec
# Out:
# [InputSpec(shape=(None, 224, 224, 3), ndim=4)]

# %%
mobile.layers
# Out:
# [<InputLayer name=input_layer, built=True>,
#  <Conv2D name=conv1, built=True>,
#  <BatchNormalization name=conv1_bn, built=True>,
#  <ReLU name=conv1_relu, built=True>,
#  <DepthwiseConv2D name=conv_dw_1, built=True>,
#  <BatchNormalization name=conv_dw_1_bn, built=True>,
#  <ReLU name=conv_dw_1_relu, built=True>,
#  <Conv2D name=conv_pw_1, built=True>,
#  <BatchNormalization name=conv_pw_1_bn, built=True>,
#  <ReLU name=conv_pw_1_relu, built=True>,
#  <ZeroPadding2D name=conv_pad_2, built=True>,
#  <DepthwiseConv2D name=conv_dw_2, built=True>,
#  <BatchNormalization name=conv_dw_2_bn, built=True>,
#  <ReLU name=conv_dw_2_relu, built=True>,
#  <Conv2D name=conv_pw_2, built=True>,
#  <BatchNormalization name=conv_pw_2_bn, built=True>,
#  <ReLU name=conv_pw_2_relu, built=True>,
#  <DepthwiseConv2D name=conv_dw_3, built=True>,
#  <BatchNormalization name=conv_dw_3_bn, built=True>,
#  <ReLU name=conv_dw_3_relu, built=True>,
#  <Conv2D name=conv_pw_3, built=True>,
# ...

# %%
mobile.summary()
# Out:
# Model: "mobilenet_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 112, 112, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 112, 112, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 112, 112, 32)   │           288 │
# ...

# %%
mobile.get_layer
# Out:
# <bound method Model.get_layer of <Functional name=mobilenet_1.00_224, built=True>>

# %%
mobile.get_config()
# Out:
# {'name': 'mobilenet_1.00_224',
#  'trainable': True,
#  'layers': [{'module': 'keras.layers',
#    'class_name': 'InputLayer',
#    'config': {'batch_shape': (None, 224, 224, 3),
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_layer'},
#    'registered_name': None,
#    'name': 'input_layer',
#    'inbound_nodes': []},
#   {'module': 'keras.layers',
#    'class_name': 'Conv2D',
#    'config': {'name': 'conv1',
#     'trainable': True,
#     'dtype': {'module': 'keras',
#      'class_name': 'DTypePolicy',
#      'config': {'name': 'float32'},
#      'registered_name': None},
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (2, 2),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'groups': 1,
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'module': 'keras.initializers',
#      'class_name': 'GlorotUniform',
#      'config': {'seed': None},
# ...

# %%
mobile.get_config().keys()
# Out:
# dict_keys(['name', 'trainable', 'layers', 'input_layers', 'output_layers'])

# %%
len(mobile.get_config()['layers'])
# Out:
# 91

# %%
mobile.get_config()['trainable']
# Out:
# True

# %%
mobile.get_config()['name']
# Out:
# 'mobilenet_1.00_224'

# %%
mobile.get_weights
# Out:
# <bound method Layer.get_weights of <Functional name=mobilenet_1.00_224, built=True>>

# %%
mobile.get_weights()[5].shape
# Out:
# (3, 3, 32, 1)

# %% [markdown]
# ## Using Tensorflow
#
# Getting the Layer names
#
#
# remmeber: KEras is backend of tensorflow
# so alwasts tf.keras avilabel

# %%
import tensorflow as tf
dir(tf.keras.applications)
# Out:
# ['ConvNeXtBase',
#  'ConvNeXtLarge',
#  'ConvNeXtSmall',
#  'ConvNeXtTiny',
#  'ConvNeXtXLarge',
#  'DenseNet121',
#  'DenseNet169',
#  'DenseNet201',
#  'EfficientNetB0',
#  'EfficientNetB1',
#  'EfficientNetB2',
#  'EfficientNetB3',
#  'EfficientNetB4',
#  'EfficientNetB5',
#  'EfficientNetB6',
#  'EfficientNetB7',
#  'EfficientNetV2B0',
#  'EfficientNetV2B1',
#  'EfficientNetV2B2',
#  'EfficientNetV2B3',
#  'EfficientNetV2L',
#  'EfficientNetV2M',
#  'EfficientNetV2S',
#  'InceptionResNetV2',
#  'InceptionV3',
#  'MobileNet',
#  'MobileNetV2',
#  'MobileNetV3Large',
#  'MobileNetV3Small',
#  'NASNetLarge',
#  'NASNetMobile',
#  'ResNet101',
#  'ResNet101V2',
#  'ResNet152',
#  'ResNet152V2',
#  'ResNet50',
#  'ResNet50V2',
#  'VGG16',
#  'VGG19',
#  'Xception',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'convnext',
#  'densenet',
#  'efficientnet',
#  'efficientnet_v2',
# ...

# %%
mobile=tf.keras.applications.MobileNetV2()

# %%
dir(mobile)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_adjust_input_rank',
#  '_aggregate_additional_loss',
#  '_allow_non_tensor_positional_args',
#  '_api_export_path',
#  '_api_export_symbol_id',
#  '_assert_compile_called',
#  '_assert_input_compatibility',
#  '_assign_variable_values',
#  '_auto_config',
#  '_build_by_run_for_kwargs',
#  '_build_by_run_for_single_pos_arg',
#  '_build_shapes_dict',
#  '_call_has_mask_arg',
#  '_call_has_training_arg',
#  '_call_signature',
#  '_called',
# ...

# %%
mobile.input
# Out:
# <KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor_247>

# %%
mobile.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
mobile.layers
# Out:
# [<InputLayer name=input_layer_2, built=True>,
#  <Conv2D name=Conv1, built=True>,
#  <BatchNormalization name=bn_Conv1, built=True>,
#  <ReLU name=Conv1_relu, built=True>,
#  <DepthwiseConv2D name=expanded_conv_depthwise, built=True>,
#  <BatchNormalization name=expanded_conv_depthwise_BN, built=True>,
#  <ReLU name=expanded_conv_depthwise_relu, built=True>,
#  <Conv2D name=expanded_conv_project, built=True>,
#  <BatchNormalization name=expanded_conv_project_BN, built=True>,
#  <Conv2D name=block_1_expand, built=True>,
#  <BatchNormalization name=block_1_expand_BN, built=True>,
#  <ReLU name=block_1_expand_relu, built=True>,
#  <ZeroPadding2D name=block_1_pad, built=True>,
#  <DepthwiseConv2D name=block_1_depthwise, built=True>,
#  <BatchNormalization name=block_1_depthwise_BN, built=True>,
#  <ReLU name=block_1_depthwise_relu, built=True>,
#  <Conv2D name=block_1_project, built=True>,
#  <BatchNormalization name=block_1_project_BN, built=True>,
# ...

# %%
mobile.get_config
# Out:
# <bound method Functional.get_config of <Functional name=mobilenetv2_1.00_224, built=True>>

# %%
len(mobile.get_config()['layers'])
# Out:
# 156

# %%
len(mobile.layers)
# Out:
# 156

# %%
mobile.layers[0].name # Input layer
mobile.layers[1].name # Conv
mobile.layers[2].name #
mobile.lad

# %%
import tensorflow as tf

#Load the MobileNetV2 model
model=tf.keras.applications.MobileNetV2()

#Get the names of all layers in the model
layers_name=[layer.name for layer in model.layers]

#Print the layer name
print(layers_name)
print(len(layers_name))

#it is version2 :156 for v1:91
# Out:
# ['input_layer_5', 'Conv1', 'bn_Conv1', 'Conv1_relu', 'expanded_conv_depthwise', 'expanded_conv_depthwise_BN', 'expanded_conv_depthwise_relu', 'expanded_conv_project', 'expanded_conv_project_BN', 'block_1_expand', 'block_1_expand_BN', 'block_1_expand_relu', 'block_1_pad', 'block_1_depthwise', 'block_1_depthwise_BN', 'block_1_depthwise_relu', 'block_1_project', 'block_1_project_BN', 'block_2_expand', 'block_2_expand_BN', 'block_2_expand_relu', 'block_2_depthwise', 'block_2_depthwise_BN', 'block_2_depthwise_relu', 'block_2_project', 'block_2_project_BN', 'block_2_add', 'block_3_expand', 'block_3_expand_BN', 'block_3_expand_relu', 'block_3_pad', 'block_3_depthwise', 'block_3_depthwise_BN', 'block_3_depthwise_relu', 'block_3_project', 'block_3_project_BN', 'block_4_expand', 'block_4_expand_BN', 'block_4_expand_relu', 'block_4_depthwise', 'block_4_depthwise_BN', 'block_4_depthwise_relu', 'block_4_project', 'block_4_project_BN', 'block_4_add', 'block_5_expand', 'block_5_expand_BN', 'block_5
# ...

# %%
for i in layers_name:
  print(i)
# Out:
# input_layer_5
# Conv1
# bn_Conv1
# Conv1_relu
# expanded_conv_depthwise
# expanded_conv_depthwise_BN
# expanded_conv_depthwise_relu
# expanded_conv_project
# expanded_conv_project_BN
# block_1_expand
# block_1_expand_BN
# block_1_expand_relu
# block_1_pad
# block_1_depthwise
# block_1_depthwise_BN
# block_1_depthwise_relu
# block_1_project
# block_1_project_BN
# block_2_expand
# block_2_expand_BN
# block_2_expand_relu
# block_2_depthwise
# block_2_depthwise_BN
# block_2_depthwise_relu
# block_2_project
# block_2_project_BN
# block_2_add
# block_3_expand
# block_3_expand_BN
# block_3_expand_relu
# block_3_pad
# block_3_depthwise
# block_3_depthwise_BN
# block_3_depthwise_relu
# block_3_project
# block_3_project_BN
# block_4_expand
# block_4_expand_BN
# block_4_expand_relu
# block_4_depthwise
# block_4_depthwise_BN
# block_4_depthwise_relu
# block_4_project
# block_4_project_BN
# block_4_add
# block_5_expand
# block_5_expand_BN
# block_5_expand_relu
# block_5_depthwise
# ...

# %%
model.name
# Out:
# 'mobilenetv2_1.00_224'

# %%
from re import L
len(model.trainable_weights)
# Out:
# 158

# %%
#load the MobileNetV2 model
model=tf.keras.applications.MobileNetV2()

# Count the number od parameters

num_params=sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

#Print the number of paramaters
print('Number of paramaetes', num_params)
# Out:
# Number of paramaetes 3504872

# %%
#Get the number of classes
num_classes=model.output_shape[-1]

#print the number of classes
print('Number of classes:',num_classes)
# Out:
# Number of classes: 1000

# %%
import tensorflow as tf

#Load the MobileNetV2model
model
# Out:
# <Functional name=mobilenetv2_1.00_224, built=True>

# %%
import tensorflow as tf

# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()

# Load ImageNet class names
class_names_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
with open(class_names_path, 'r') as f:
    class_names = f.read().splitlines()

# Print the class names
print("Class names:", class_names)
# Out:
# ...
# 10484/10484 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...

# %%
len(class_names)
# Originally 1000
# but we are seeing 1001
# first one is dummy leave that
# python index start with 0
# when we do prediction +1
# Out:
# 1001

# %% [markdown]
# ## plot model
# - it is not avialable for all model beacouse of size

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model

# Load the MobileNetV2 model
model = tf.keras.applications.MobileNetV2()

# Plot the model architecture
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
from  IPython.display import Image
Image(filename='/content/Iron Man.jpeg')

# %% [markdown]
# we can load the image using
#
# 1.Keras.preprocessing
#
# 2.Pillow
#
# 3.OpenCV
#
# 4.Matplotlib
#
# 5.IPythonDisplay
#
#     - MobileNet input image shape=224,224
#
#     - we need to reshape the image
#
#     - that we can do using numpy or using keras

# %%
# Read the image using keras

import keras

dir(keras.preprocessing)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'image',
#  'image_dataset_from_directory',
#  'sequence',
#  'text_dataset_from_directory',
#  'timeseries_dataset_from_array']

# %%
from keras.preprocessing import image

# %%
img=image.load_img('/content/Iron Man.jpeg')
print(img.size) #(w,h)
print(img.width,img.height)
# Out:
# (275, 183)
# 275 183

# %%
img.resize((224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img=image.load_img('/content/Iron Man.jpeg',target_size=(224,224))
print(img.size) #(w,h)
print(img.width,img.height)
# Out:
# (224, 224)
# 224 224

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img.size
# Out:
# (224, 224)

# %%
image will give the values by applying

image.img_to_array

# %%
#conver image to array
from keras.preprocessing import image
img_array=image.img_to_array(img)
img_array.shape
# Out:
# (224, 224, 3)

# %%
import numpy as np
img_array_expalnded_dims=np.expand_dims(img_array,axis=0)
img_array_expalnded_dims.shape
# Out:
# (1, 224, 224, 3)

# %%
(model.predict(img_array_expalnded_dims))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# array([[3.29576396e-05, 1.09710752e-04, 1.78088230e-05, 8.79929121e-06,
#         1.23044578e-04, 1.97894387e-05, 1.05490690e-04, 1.10441069e-04,
#         1.45531958e-05, 3.11100535e-04, 2.30798487e-05, 1.40671027e-05,
#         8.75370533e-05, 7.17872172e-05, 6.28431662e-05, 1.11311456e-05,
#         6.36473997e-05, 1.57332524e-05, 3.18650746e-05, 3.98758566e-05,
#         1.63052755e-04, 2.76483679e-05, 1.95785924e-05, 6.57168675e-06,
#         5.72109529e-05, 4.28700696e-05, 7.84326912e-05, 6.92432804e-05,
#         1.32996547e-05, 1.12258867e-05, 5.16582877e-05, 2.34949621e-05,
#         4.54996298e-05, 9.69758912e-06, 3.93760492e-05, 4.12570691e-04,
#         3.70561538e-05, 6.65383632e-05, 3.71240312e-05, 7.53785789e-05,
#         7.98657220e-06, 1.14219823e-04, 1.39009489e-05, 1.13254182e-05,
#         4.11981891e-05, 2.86710911e-05, 4.68710714e-05, 2.96001708e-05,
#         1.21211660e-05, 2.66086081e-05, 7.13041709e-06, 1.36485096e-05,
# ...

# %%
preprocess_image=keras.applications.mobilenet.preprocess_input(img_array_expalnded_dims)
preprocess_image.shape
# Out:
# (1, 224, 224, 3)

# %%
len(preprocess_image)
# Out:
# 1

# %%
prediction_v2=model.predict(preprocess_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step

# %%
np.argmax(prediction_v2)
# Out:
# np.int64(818)

# %%
class_names[np.argmax(prediction_v2)]
# Out:
# 'sports car'

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
result=imagenet_utils.decod
