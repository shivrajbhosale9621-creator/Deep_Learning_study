# %% [markdown]
# ## Haar cascade
#
# - IT is an boject detection  method

# %%
import cv2
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## load the Frontal face filter

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
dir(face_cascade)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'convert',
#  'detectMultiScale',
#  'detectMultiScale2',
#  'detectMultiScale3',
#  'empty',
#  'getFeatureType',
#  'getOriginalWindowSize',
#  'isOldFormatCascade',
#  'load',
#  'read']

# %%
img=cv2.imread(r"C:\Data Sets\Iron man 2.jpg",cv2.COLOR_BGR2RGB)
cv2.imshow('Iron man',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
faces=face_cascade.detectMultiScale(img,1.1,5)# 1.1 is scaling and 5 is how  many neighobur to consideer

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,
                  (x,y),(x+w,y+h),
    (0,0,255),
    3)
    
    org=(x,y)
    color=(0,0,255)
    fontFace = cv2.FONT_HERSHEY_SIMPLEX
    fontScale = 1.5
    cv2.putText(img,'Billiner Iron man',org,fontFace,fontScale,color)
cv2.imshow('image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
cap=cv2.VideoCapture(r"C:\Users\Shivraj\Downloads\Hukum Ft. Mahesh Babu _ Super Star _ Anirudh _ Jailer _.mp4")
while cap.isOpened(): # True or flase
    has_frame,frame=cap.read() # cap.read will give two
    image=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    face=face_cascade.detectionMultiScale(image,1.1,4)
    for (x,y,w,h) in faces:
        cv2.rectuangle(image,(x,y),(x+h,y+w),(255,0,0),3)
    cv2.imshow('image',image)
    if cv2.waitkey(1) & 0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       4 has_frame,frame=cap.read() # cap.read will give two
#       5 image=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# ----> 6 face=face_cascade.detectionMultiScale(image,1.1,4)
#       7 for (x,y,w,h) in faces:
#       8     cv2.rectuangle(image,(x,y),(x+h,y+w),(255,0,0),3)
#
# AttributeError: 'cv2.CascadeClassifier' object has no attribute 'detectionMultiScale'

# %%
import cv2

# Load the cascade classifier for face detection
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Open the video file
cap = cv2.VideoCapture(r"C:\Users\Shivraj\Downloads\Hukum Ft. Mahesh Babu _ Super Star _ Anirudh _ Jailer _.mp4")

while cap.isOpened():
    has_frame, frame = cap.read()
    if not has_frame:
        break

    # Convert frame to grayscale
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(image, scaleFactor=1.1, minNeighbors=4)

    # Draw rectangle around faces
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 3)

    # Show the frame
    cv2.imshow('image', image)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video and close all windows
cap.release()
cv2.destroyAllWindows()
